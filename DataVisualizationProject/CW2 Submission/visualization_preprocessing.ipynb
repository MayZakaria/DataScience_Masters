# %%
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import date
from pandas import Timestamp

import seaborn as sns
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 2)
# %matplotlib inline
# Extra Libs
from IPython.display import HTML, display


import matplotlib.dates as mdates
from IPython.display import HTML, display

# %%
df = pd.read_excel('/results-for-employee-job-2023-09-02-2010.xlsx',engine='openpyxl')

# %%
replacement_mapping = {
    0: 'Strongly Agree',
    1: 'Agree',
    2: 'Neutral',
    3: 'Disagree',
    4: 'Strongly Disagree'
}

# Replace values in the specified column
column_name = 'To what extent do you feel that your current job helps you to achieve a healthy work-life balance (meeting up with friends, playing sports, reading books, doing a hobby, meeting up with family members)?'
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
replacement_mapping = {
    0: 'Strongly Agree',
    1: 'Agree',
    2: 'Neutral',
    3: 'Disagree',
    4: 'Strongly Disagree'
}

# Specify the column name
column_name = 'To what extent do feel that management/supervisor support (such as encouraging personal time off and work breaks, setting reasonable workloads) influences your work-life balance?'

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Fully remote',
    1: 'Hybrid (e.g. 2 or 3 days to work from home)',
    2: 'Fully office-based',
    3: 'No preference'
}

# Specify the column name
column_name = 'What is the work arrangement type you prefer/wish for your current job?'

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Fully remote',
    1: 'Hybrid (e.g. 2 or 3 days to work from home)',
    2: 'Fully office-based'
}

# Specify the column name
column_name = 'What is your current work arrangement type for your job?'

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Strongly Agree',
    1: 'Agree',
    2: 'Neutral',
    3: 'Disagree',
    4: 'Strongly Disagree'
}

# Specify the column name
column_name = "To what extent do you think that your current work arrangement provides you with the resources and tools needed that help you to fulfill your job effectively? (Example: you were given a MyFi/Mobile Bundle while working from home, while working from the office it's calm and quiet which helps you focus on your daily tasks)"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Strongly Agree',
    1: 'Agree',
    2: 'Neutral',
    3: 'Disagree',
    4: 'Strongly Disagree'
}

# Specify the column name
column_name = "To what extent do you feel that gender diversity within your organization positively affects collaboration, innovation, problem-solving, and overall productivity?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Yes, I feel my workplace provides equal pay and benefits rights between genders',
    1: 'No, I feel my workplace is biased towards a particular gender in terms of pay and benefits',
    2: "Not sure (e.g. don't have enough information)",
    3: 'Not applicable in my company'
}

# Specify the column name
column_name = "Do you feel your current workplace provides equal pay and benefits rights between genders or it is biased towards a particular gender?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Very Satisfied',
    1: 'Satisfied',
    2: 'Neutral',
    3: 'Dissatisfied',
    4: 'Very Dissatisfied'
}

# Specify the column name
column_name = "What is your overall job satisfaction assessment?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Healthcare and Pharmaceuticals Sector',
    1: 'IT and Software Development',
    2: 'Financial Services and Banking Sector',
    3: 'Manufacturing and Engineering Sector',
    4: 'Education and Academia Sector',
    5: 'Retail and Consumer Goods',
    6: 'Hospitality and Tourism',
    7: 'Professional Services (Law, Accounting, Consulting)',
    8: 'Government and Public Administration',
    9: 'Nonprofit and Social Services',
    10: 'Media and Entertainment',
    11: 'Energy and Utilities',
    12: 'Construction and Real Estate',
    13: 'Automotive and Transportation'
}

# Specify the column name
column_name = "In which industry do you work?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: '18-24',
    1: '25-34',
    2: '35-44',
    3: '45-54',
    4: '55-64',
    5: '65+',
    6: '65+',
    7: '65+'
}

# Specify the column name
column_name = "What is your age group?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Female',
    1: 'Male',
    2: 'Other',
    3: 'Prefer not to say'
}

# Specify the column name
column_name = "What is your gender?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: '11-50',
    1: '51-200',
    2: '201-500',
    3: '501-1000',
    4: '1001-10000',
    5: '10000+'
}

# Specify the column name
column_name = "What is your company size?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
# Define the mapping of values to replacements
replacement_mapping = {
    0: 'Full-time employee',
    1: 'Part-time employee',
    2: 'Self-employed or freelancer',
    3: 'Unemployed',
    4: 'Work Student',
    5: 'Full-time employed and studying'
}

# Specify the column name
column_name = "What is your current employment status?"

# Replace values in the specified column
df[column_name] = df[column_name].replace(replacement_mapping)

# %%
df.to_excel('/cleaned_Data.xlsx')

# %%
df.head(10)
# Out:
#              URN              In-person meetings or one-on-one discussions  Written feedback via email or messaging  Formal performance reviews or evaluations  Informal check-ins or regular feedback sessions  Public recognition in team meetings or company-wide announcements  Constructive feedback with specific examples and actionable suggestions  Written or digital documentation of accomplishments or milestones  Peer recognition or feedback  Unnamed: 9  In-person meetings  Phone or voice calls  Email  Instant messaging or chat platforms  Video conferencing  Face-to-face discussions  Written memos or notes  Unnamed: 17  Salary  Career advancement  Recognition, appreciation and rewards  Opportunities for skills development & learning  Job stability/security (e.g. low turnover rate)  Supportive colleagues and management  Autonomy, independence and decision-making authority  Positive workplace relationships  Competitive compensation and benefits  Work-life balance  \
# ...
